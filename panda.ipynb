# %% [markdown]
# **About Dataset**:
# - This data set contains yearly suicide detail of all the states/u.t of India by various parameters from 2001 to 2012.
# - Parameters:
# - Suicide causes
# - Education status
# - By means adopted
# - Professional profile
# - Social status

# %% [markdown]
# **Reading CSV file into Dataframe and diplaying the information with below code**

# %%
import pandas as pd
df = pd.read_csv('Suicides in India 2001-2012.csv')
df
# Out:
#                 State  Year      Type_code  \
# 0       A & N Islands  2001         Causes
# 1       A & N Islands  2001         Causes
# 2       A & N Islands  2001         Causes
# 3       A & N Islands  2001         Causes
# 4       A & N Islands  2001         Causes
# ...               ...   ...            ...
# 237514    West Bengal  2012  Social_Status
# 237515    West Bengal  2012  Social_Status
# 237516    West Bengal  2012  Social_Status
# 237517    West Bengal  2012  Social_Status
# 237518    West Bengal  2012  Social_Status
#
#                                            Type  Gender Age_group  Total
# 0                            Illness (Aids/STD)  Female      0-14      0
# 1       Bankruptcy or Sudden change in Economic  Female      0-14      0
# 2       Cancellation/Non-Settlement of Marriage  Female      0-14      0
# 3             Physical Abuse (Rape/Incest Etc.)  Female      0-14      0
# 4                                 Dowry Dispute  Female      0-14      0
# ...

# %% [markdown]
# **The head function displays top 5 rows of the csv file**

# %%
df.head()
# Out:
#            State  Year Type_code                                     Type  \
# 0  A & N Islands  2001    Causes                       Illness (Aids/STD)
# 1  A & N Islands  2001    Causes  Bankruptcy or Sudden change in Economic
# 2  A & N Islands  2001    Causes  Cancellation/Non-Settlement of Marriage
# 3  A & N Islands  2001    Causes        Physical Abuse (Rape/Incest Etc.)
# 4  A & N Islands  2001    Causes                            Dowry Dispute
#
#    Gender Age_group  Total
# 0  Female      0-14      0
# 1  Female      0-14      0
# 2  Female      0-14      0
# 3  Female      0-14      0
# 4  Female      0-14      0

# %% [markdown]
# **head function with parameter n displays top n rows of the file**

# %%
df.head(15)
# Out:
#             State  Year Type_code                                     Type  \
# 0   A & N Islands  2001    Causes                       Illness (Aids/STD)
# 1   A & N Islands  2001    Causes  Bankruptcy or Sudden change in Economic
# 2   A & N Islands  2001    Causes  Cancellation/Non-Settlement of Marriage
# 3   A & N Islands  2001    Causes        Physical Abuse (Rape/Incest Etc.)
# 4   A & N Islands  2001    Causes                            Dowry Dispute
# 5   A & N Islands  2001    Causes                          Family Problems
# 6   A & N Islands  2001    Causes      Ideological Causes/Hero Worshipping
# 7   A & N Islands  2001    Causes                  Other Prolonged Illness
# 8   A & N Islands  2001    Causes                         Property Dispute
# 9   A & N Islands  2001    Causes                Fall in Social Reputation
# 10  A & N Islands  2001    Causes                   Illegitimate Pregnancy
# ...

# %% [markdown]
# **the tail function displays the last 5 rows of the csv file**

# %%
df.tail()
# Out:
#               State  Year      Type_code             Type Gender Age_group  \
# 237514  West Bengal  2012  Social_Status        Seperated   Male    0-100+
# 237515  West Bengal  2012  Social_Status  Widowed/Widower   Male    0-100+
# 237516  West Bengal  2012  Social_Status          Married   Male    0-100+
# 237517  West Bengal  2012  Social_Status         Divorcee   Male    0-100+
# 237518  West Bengal  2012  Social_Status    Never Married   Male    0-100+
#
#         Total
# 237514    149
# 237515    233
# 237516   5451
# 237517    189
# 237518   2658

# %% [markdown]
# **tail function with parameter n displays last n rows of the file**

# %%
df.tail(20)
# Out:
#               State  Year             Type_code  \
# 237499  West Bengal  2012  Professional_Profile
# 237500  West Bengal  2012  Professional_Profile
# 237501  West Bengal  2012  Professional_Profile
# 237502  West Bengal  2012  Professional_Profile
# 237503  West Bengal  2012  Professional_Profile
# 237504  West Bengal  2012  Professional_Profile
# 237505  West Bengal  2012  Professional_Profile
# 237506  West Bengal  2012  Professional_Profile
# 237507  West Bengal  2012  Professional_Profile
# 237508  West Bengal  2012  Professional_Profile
# 237509  West Bengal  2012         Social_Status
# 237510  West Bengal  2012         Social_Status
# 237511  West Bengal  2012         Social_Status
# 237512  West Bengal  2012         Social_Status
# 237513  West Bengal  2012         Social_Status
# 237514  West Bengal  2012         Social_Status
# 237515  West Bengal  2012         Social_Status
# 237516  West Bengal  2012         Social_Status
# ...

# %% [markdown]
# **USE OF SLICING (first index to lastindex-1)**:All rows from first index are displayed except the last one

# %%
df[100:110]
# Out:
#              State  Year Type_code                                      Type  \
# 100  A & N Islands  2001    Causes                    Failure in Examination
# 101  A & N Islands  2001    Causes                              Unemployment
# 102  A & N Islands  2001    Causes                                   Divorce
# 103  A & N Islands  2001    Causes                          Causes Not known
# 104  A & N Islands  2001    Causes   Cancellation/Non-Settlement of Marriage
# 105  A & N Islands  2001    Causes                                   Divorce
# 106  A & N Islands  2001    Causes                      Drug Abuse/Addiction
# 107  A & N Islands  2001    Causes  Not having Children(Barrenness/Impotency
# 108  A & N Islands  2001    Causes                   Other Prolonged Illness
# 109  A & N Islands  2001    Causes         Physical Abuse (Rape/Incest Etc.)
#
#      Gender Age_group  Total
# 100    Male     15-29      1
# 101    Male     15-29      0
# 102    Male     15-29      0
# ...

# %% [markdown]
# **USE OF DESCRIBE FUNCTION** -
# If the DataFrame contains numerical data, the description contains these information for each column:
# - count - The number of not-empty values.
# - mean - The average (mean) value.
# - std - The standard deviation.
# - min - the minimum value.
# - 25% - The 25% percentile*
# - 50% - The 50% percentile*.
# - 75% - The 75% percentile*.
# - max - the maximum value.
# - **percentile means that how many values are less than the given percentile**

# %%
df.describe()
# Out:
#                 Year          Total
# count  237519.000000  237519.000000
# mean     2006.500448      55.034477
# std         3.452240     792.749038
# min      2001.000000       0.000000
# 25%      2004.000000       0.000000
# 50%      2007.000000       0.000000
# 75%      2010.000000       6.000000
# max      2012.000000   63343.000000

# %% [markdown]
# **Info function of dataframe** : It provides name of the data frame columns, total non null values of each column and their data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237519 entries, 0 to 237518
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   State      237519 non-null  object
#  1   Year       237519 non-null  int64
#  2   Type_code  237519 non-null  object
#  3   Type       237519 non-null  object
#  4   Gender     237519 non-null  object
#  5   Age_group  237519 non-null  object
#  6   Total      237519 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 12.7+ MB

# %% [markdown]
# **DataFrame.columns attribute returns the column labels of the given Dataframe**

# %%
df.columns
# Out:
# Index(['State', 'Year', 'Type_code', 'Type', 'Gender', 'Age_group', 'Total'], dtype='object')

# %%
df['State'].unique()
# Out:
# array(['A & N Islands', 'Andhra Pradesh', 'Arunachal Pradesh', 'Assam',
#        'Bihar', 'Chandigarh', 'Chhattisgarh', 'D & N Haveli',
#        'Daman & Diu', 'Delhi (Ut)', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Lakshadweep', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha',
#        'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Total (All India)', 'Total (States)', 'Total (Uts)', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal'], dtype=object)

# %% [markdown]
# **value_counts()**: It is a function that returns a series containing counts of unique rows in the data frame

# %%
df['State'].value_counts()
# Out:
# Madhya Pradesh       6792
# Maharashtra          6792
# Karnataka            6792
# Odisha               6791
# Andhra Pradesh       6791
# Rajasthan            6791
# Bihar                6790
# Chhattisgarh         6790
# Haryana              6790
# Kerala               6788
# Uttar Pradesh        6787
# Assam                6786
# Tamil Nadu           6786
# Gujarat              6786
# Jharkhand            6785
# Tripura              6782
# Delhi (Ut)           6782
# West Bengal          6780
# Punjab               6779
# Himachal Pradesh     6774
# Jammu & Kashmir      6761
# Goa                  6759
# Uttarakhand          6758
# Sikkim               6742
# Mizoram              6737
# Meghalaya            6733
# Puducherry           6730
# Chandigarh           6717
# A & N Islands        6712
# Daman & Diu          6710
# Arunachal Pradesh    6707
# Nagaland             6705
# D & N Haveli         6704
# Manipur              6700
# Lakshadweep          6674
# ...

# %% [markdown]
# **All columns and rows are displayed with df command**

# %%
df
# Out:
#                 State  Year      Type_code  \
# 0       A & N Islands  2001         Causes
# 1       A & N Islands  2001         Causes
# 2       A & N Islands  2001         Causes
# 3       A & N Islands  2001         Causes
# 4       A & N Islands  2001         Causes
# ...               ...   ...            ...
# 237514    West Bengal  2012  Social_Status
# 237515    West Bengal  2012  Social_Status
# 237516    West Bengal  2012  Social_Status
# 237517    West Bengal  2012  Social_Status
# 237518    West Bengal  2012  Social_Status
#
#                                            Type  Gender Age_group  Total
# 0                            Illness (Aids/STD)  Female      0-14      0
# 1       Bankruptcy or Sudden change in Economic  Female      0-14      0
# 2       Cancellation/Non-Settlement of Marriage  Female      0-14      0
# 3             Physical Abuse (Rape/Incest Etc.)  Female      0-14      0
# 4                                 Dowry Dispute  Female      0-14      0
# ...

# %%
df[['State','Year']]
# Out:
#                 State  Year
# 0       A & N Islands  2001
# 1       A & N Islands  2001
# 2       A & N Islands  2001
# 3       A & N Islands  2001
# 4       A & N Islands  2001
# ...               ...   ...
# 237514    West Bengal  2012
# 237515    West Bengal  2012
# 237516    West Bengal  2012
# 237517    West Bengal  2012
# 237518    West Bengal  2012
#
# [237519 rows x 2 columns]

# %% [markdown]
# **Find all records of the karnataka state**

# %%
df[df["State"] == 'Karnataka']
# Out:
#             State  Year      Type_code                     Type  Gender  \
# 108144  Karnataka  2001         Causes  Insanity/Mental Illness  Female
# 108145  Karnataka  2001         Causes         Causes Not known  Female
# 108146  Karnataka  2001         Causes         Property Dispute  Female
# 108147  Karnataka  2001         Causes     Drug Abuse/Addiction  Female
# 108148  Karnataka  2001         Causes                   Cancer  Female
# ...           ...   ...            ...                      ...     ...
# 114931  Karnataka  2012  Social_Status                Seperated    Male
# 114932  Karnataka  2012  Social_Status                  Married    Male
# 114933  Karnataka  2012  Social_Status            Never Married    Male
# 114934  Karnataka  2012  Social_Status          Widowed/Widower    Male
# 114935  Karnataka  2012  Social_Status                 Divorcee    Male
#
#        Age_group  Total
# 108144      0-14     11
# 108145      0-14     42
# 108146      0-14      0
# ...

# %%
df['Gender'].value_counts()
# Out:
# Male      118879
# Female    118640
# Name: Gender, dtype: int64

# %% [markdown]
# **Excel conversion** : Data retrieved from dataframe can be exported to excel with to_excel function

# %%
year_2010 = df[df['Year'] == 2010]
year_2010.to_excel('year_2010.xlsx')

# %% [markdown]
# **Filtering Data** : In order to Filter data according to the column value, we can use below code

# %%
df2 = df[(df['State'] == 'West Bengal') & (df['Year'] == 2010) & (df['Gender'] == 'Male')]
df2.shape
# Out:
# (283, 7)

# %%
df2
# Out:
#               State  Year      Type_code                               Type  \
# 235857  West Bengal  2010         Causes  Physical Abuse (Rape/Incest Etc.)
# 235858  West Bengal  2010         Causes                    Family Problems
# 235859  West Bengal  2010         Causes            Insanity/Mental Illness
# 235860  West Bengal  2010         Causes                 Illness (Aids/STD)
# 235861  West Bengal  2010         Causes                            Poverty
# ...             ...   ...            ...                                ...
# 236392  West Bengal  2010  Social_Status                            Married
# 236393  West Bengal  2010  Social_Status                          Seperated
# 236394  West Bengal  2010  Social_Status                           Divorcee
# 236395  West Bengal  2010  Social_Status                      Never Married
# 236396  West Bengal  2010  Social_Status                    Widowed/Widower
#
#        Gender Age_group  Total
# ...

# %% [markdown]
# **Adding and Removing columns** :

# %% [markdown]
# In order to add column to the data frame we need to use the following code

# %%
df['New Column']='FGH'

# %%
df
# Out:
#                 State  Year      Type_code  \
# 0       A & N Islands  2001         Causes
# 1       A & N Islands  2001         Causes
# 2       A & N Islands  2001         Causes
# 3       A & N Islands  2001         Causes
# 4       A & N Islands  2001         Causes
# ...               ...   ...            ...
# 237514    West Bengal  2012  Social_Status
# 237515    West Bengal  2012  Social_Status
# 237516    West Bengal  2012  Social_Status
# 237517    West Bengal  2012  Social_Status
# 237518    West Bengal  2012  Social_Status
#
#                                            Type  Gender Age_group  Total  \
# 0                            Illness (Aids/STD)  Female      0-14      0
# 1       Bankruptcy or Sudden change in Economic  Female      0-14      0
# 2       Cancellation/Non-Settlement of Marriage  Female      0-14      0
# 3             Physical Abuse (Rape/Incest Etc.)  Female      0-14      0
# 4                                 Dowry Dispute  Female      0-14      0
# ...

# %% [markdown]
# In order to remove column permanently, we need to assign unit value to axis parameter

# %%
df.drop('New Column',axis=1,inplace=True)

# %%
df
# Out:
#                 State  Year      Type_code  \
# 0       A & N Islands  2001         Causes
# 1       A & N Islands  2001         Causes
# 2       A & N Islands  2001         Causes
# 3       A & N Islands  2001         Causes
# 4       A & N Islands  2001         Causes
# ...               ...   ...            ...
# 237514    West Bengal  2012  Social_Status
# 237515    West Bengal  2012  Social_Status
# 237516    West Bengal  2012  Social_Status
# 237517    West Bengal  2012  Social_Status
# 237518    West Bengal  2012  Social_Status
#
#                                            Type  Gender Age_group  Total
# 0                            Illness (Aids/STD)  Female      0-14      0
# 1       Bankruptcy or Sudden change in Economic  Female      0-14      0
# 2       Cancellation/Non-Settlement of Marriage  Female      0-14      0
# 3             Physical Abuse (Rape/Incest Etc.)  Female      0-14      0
# 4                                 Dowry Dispute  Female      0-14      0
# ...

# %% [markdown]
# **Renaming the Columns** : In order to change Type and Total column labels pass the old and new column names as parameter in the rename function

# %%
df.rename(columns={'Type': 'Cause','Total': 'Complete Total'})
# Out:
#                 State  Year      Type_code  \
# 0       A & N Islands  2001         Causes
# 1       A & N Islands  2001         Causes
# 2       A & N Islands  2001         Causes
# 3       A & N Islands  2001         Causes
# 4       A & N Islands  2001         Causes
# ...               ...   ...            ...
# 237514    West Bengal  2012  Social_Status
# 237515    West Bengal  2012  Social_Status
# 237516    West Bengal  2012  Social_Status
# 237517    West Bengal  2012  Social_Status
# 237518    West Bengal  2012  Social_Status
#
#                                           Cause  Gender Age_group  \
# 0                            Illness (Aids/STD)  Female      0-14
# 1       Bankruptcy or Sudden change in Economic  Female      0-14
# 2       Cancellation/Non-Settlement of Marriage  Female      0-14
# 3             Physical Abuse (Rape/Incest Etc.)  Female      0-14
# 4                                 Dowry Dispute  Female      0-14
# ...

# %% [markdown]
# **Reordering the Columns** : We can change the order of the column labels by passing new series as list.

# %%
df.columns
# Out:
# Index(['State', 'Year', 'Type_code', 'Type', 'Gender', 'Age_group', 'Total'], dtype='object')

# %%
df=df[['State', 'Type_code','Year', 'Type', 'Gender', 'Age_group', 'Total']]

# %%
df
# Out:
#                 State      Type_code  Year  \
# 0       A & N Islands         Causes  2001
# 1       A & N Islands         Causes  2001
# 2       A & N Islands         Causes  2001
# 3       A & N Islands         Causes  2001
# 4       A & N Islands         Causes  2001
# ...               ...            ...   ...
# 237514    West Bengal  Social_Status  2012
# 237515    West Bengal  Social_Status  2012
# 237516    West Bengal  Social_Status  2012
# 237517    West Bengal  Social_Status  2012
# 237518    West Bengal  Social_Status  2012
#
#                                            Type  Gender Age_group  Total
# 0                            Illness (Aids/STD)  Female      0-14      0
# 1       Bankruptcy or Sudden change in Economic  Female      0-14      0
# 2       Cancellation/Non-Settlement of Marriage  Female      0-14      0
# 3             Physical Abuse (Rape/Incest Etc.)  Female      0-14      0
# 4                                 Dowry Dispute  Female      0-14      0
# ...

# %% [markdown]
# **Appending and Resetting Index** : Filtered data frames can be easily combined together in the following example.
# df2 and df3 dataframes consist of top 5 and last 5 rows respectively.

# %%
df2=df.head()
df3=df.tail()
#df1=df2.append(df3)
df1=pd.concat([df2,df3],axis=0)
df1
# Out:
#                 State      Type_code  Year  \
# 0       A & N Islands         Causes  2001
# 1       A & N Islands         Causes  2001
# 2       A & N Islands         Causes  2001
# 3       A & N Islands         Causes  2001
# 4       A & N Islands         Causes  2001
# 237514    West Bengal  Social_Status  2012
# 237515    West Bengal  Social_Status  2012
# 237516    West Bengal  Social_Status  2012
# 237517    West Bengal  Social_Status  2012
# 237518    West Bengal  Social_Status  2012
#
#                                            Type  Gender Age_group  Total
# 0                            Illness (Aids/STD)  Female      0-14      0
# 1       Bankruptcy or Sudden change in Economic  Female      0-14      0
# 2       Cancellation/Non-Settlement of Marriage  Female      0-14      0
# 3             Physical Abuse (Rape/Incest Etc.)  Female      0-14      0
# 4                                 Dowry Dispute  Female      0-14      0
# ...

# %% [markdown]
# In the above code the df1 dataframe retains old index values, therefore we need to reset the index staring from 0. In order to remove old index,use drop=True parameter

# %%
df1.reset_index(drop=True)
# Out:
#            State      Type_code  Year  \
# 0  A & N Islands         Causes  2001
# 1  A & N Islands         Causes  2001
# 2  A & N Islands         Causes  2001
# 3  A & N Islands         Causes  2001
# 4  A & N Islands         Causes  2001
# 5    West Bengal  Social_Status  2012
# 6    West Bengal  Social_Status  2012
# 7    West Bengal  Social_Status  2012
# 8    West Bengal  Social_Status  2012
# 9    West Bengal  Social_Status  2012
#
#                                       Type  Gender Age_group  Total
# 0                       Illness (Aids/STD)  Female      0-14      0
# 1  Bankruptcy or Sudden change in Economic  Female      0-14      0
# 2  Cancellation/Non-Settlement of Marriage  Female      0-14      0
# 3        Physical Abuse (Rape/Incest Etc.)  Female      0-14      0
# 4                            Dowry Dispute  Female      0-14      0
# 5                                Seperated    Male    0-100+    149
# ...

# %% [markdown]
# **ILOC function**: The function is used to access an individual row of the dataframe if the datatype of index is integer.For instance if we want to access 4th row the following command will accomplish the task

# %%
df1.iloc[4]
# Out:
# State        A & N Islands
# Type_code           Causes
# Year                  2001
# Type         Dowry Dispute
# Gender              Female
# Age_group             0-14
# Total                    0
# Name: 4, dtype: object

# %% [markdown]
# **LOC function**: It is also used to access the data frame wherein the index is non integer. In df1 dataframe we can make state as index and implement the LOC function.

# %%
df1=df1.set_index('State')

# %%
df1.loc['West Bengal']
# Out:
#              Year             Type Gender Age_group  Total
# State
# West Bengal  2012        Seperated   Male    0-100+    149
# West Bengal  2012  Widowed/Widower   Male    0-100+    233
# West Bengal  2012          Married   Male    0-100+   5451
# West Bengal  2012         Divorcee   Male    0-100+    189
# West Bengal  2012    Never Married   Male    0-100+   2658

# %% [markdown]
# **Groupby Function** : It is used for grouping the rows based on the distinct values in the given column or columns in data frame. For instance if we want to group the dataframe df by the column name State, it is quite easy to complete the task.

# %%
state_df=df.groupby('State')

# %%
for i in state_df:
    print(i)
# Out:
# ('A & N Islands',               State      Type_code  Year  \
# 0     A & N Islands         Causes  2001
# 1     A & N Islands         Causes  2001
# 2     A & N Islands         Causes  2001
# 3     A & N Islands         Causes  2001
# 4     A & N Islands         Causes  2001
# ...             ...            ...   ...
# 6707  A & N Islands  Social_Status  2012
# 6708  A & N Islands  Social_Status  2012
# 6709  A & N Islands  Social_Status  2012
# 6710  A & N Islands  Social_Status  2012
# 6711  A & N Islands  Social_Status  2012
#
#                                          Type  Gender Age_group  Total
# 0                          Illness (Aids/STD)  Female      0-14      0
# 1     Bankruptcy or Sudden change in Economic  Female      0-14      0
# 2     Cancellation/Non-Settlement of Marriage  Female      0-14      0
# 3           Physical Abuse (Rape/Incest Etc.)  Female      0-14      0
# 4                               Dowry Dispute  Female      0-14      0
# ...
